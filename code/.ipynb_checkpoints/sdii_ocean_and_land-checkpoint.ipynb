# %% [markdown]
# # Layering plots for PPT : SDII from CMIP6, Reanalyses and corrected Satellite

# %% [markdown]
# This Jupyter notebook plots time series of regionally averaged SDII over the ocean and land (50°S–50°N) from CMIP6 models, reanalyses, and satellite products. The data are sourced from the FROGs database (Roca et al., 2019), available at: https://frogs.ipsl.fr/download-data/.

# %%
# Import modules
# %matplotlib inline
# %run /g/data/w40/pn3424/2025/Lisa/Functions.ipynb
import matplotlib as mpl
import fnmatch
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as mticker
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle
import cartopy as cartopy
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %% [markdown]
# ## Define your region of interest with time period, season and mask

# %%
# Define region of interest: e.g., (50N-50S, 180W-180E)
lat_slice = slice(-50,50)
lon_slice = slice(-180,180)
time_slice = slice("1980-01-01", "2014-12-30")

# Define temporal scale for SPI variable (1 for 3-months, 2 for 6-months, 3 for 12-months); use "None" if not using the SPI variable
iscale = None

# Define season as a list of month numbers. If not wanting a seasonal breakdown, use None.
# Suggestions: Wet 6-month: [10,11,12,1,2,3]; Dry 6-month: [4,5,6,7,8,9]; Wet 3-month: [12,1,2]; Dry 3-month: [6,7,8]
season =  None
season_name ='Annual'

# %% [markdown]
# ## Define keywords to be used with f-strings to build the path to datasets

# %%
# Define keywords to be used with f-strings to build the path to datasets
model_type = 'gcm'
grid_type = '1degree'
time_period = 'historical'
variable = 'sdii'
temporal_resolution = 'MON'
obs_temporal_resolution = 'MON'

# Define paths to data
cmip6_data_path = '/g/data/w40/pn3424/2025/Lisa/Data/CMIP6/'

# %%
data_paths = get_model_files(cmip6_data_path)
pd.set_option('display.max_colwidth', None)
data_paths
# Out:
#         driving_gcm  \
# 0   HadGEM3-GC31-LL
# 1        CNRM-CM6-1
# 2             NESM3
# 3         INM-CM4-8
# 4        ACCESS-CM2
# 5        KACE-1-0-G
# 6       CNRM-ESM2-1
# 7     MPI-ESM1-2-HR
# 8        NorESM2-MM
# 9          GFDL-CM4
# 10  HadGEM3-GC31-MM
# 11      BCC-CSM2-MR
# 12        INM-CM5-0
# 13    CNRM-CM6-1-HR
# 14       MRI-ESM2-0
# 15    ACCESS-ESM1-5
# 16        FGOALS-g3
# 17        GFDL-ESM4
# 18    MPI-ESM1-2-LR
# 19        KIOST-ESM
# 20      UKESM1-0-LL
# 21    EC-Earth3-Veg
# 22       NorESM2-LM
# 23       MIROC-ES2L
# 24          CanESM5
#
#                                                                                  dataset_path
# 0   /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_HadGEM3-GC31-LL_historical_1950-2014_1deg.nc
# 1        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-CM6-1_historical_1950-2014_1deg.nc
# 2             /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NESM3_historical_1950-2014_1deg.nc
# 3         /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_INM-CM4-8_historical_1950-2014_1deg.nc
# 4        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_ACCESS-CM2_historical_1950-2014_1deg.nc
# 5        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_KACE-1-0-G_historical_1950-2014_1deg.nc
# 6       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-ESM2-1_historical_1950-2014_1deg.nc
# 7     /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MPI-ESM1-2-HR_historical_1950-2014_1deg.nc
# 8        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NorESM2-MM_historical_1950-2014_1deg.nc
# 9          /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_GFDL-CM4_historical_1950-2014_1deg.nc
# 10  /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_HadGEM3-GC31-MM_historical_1950-2014_1deg.nc
# 11      /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_BCC-CSM2-MR_historical_1950-2014_1deg.nc
# 12        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_INM-CM5-0_historical_1950-2014_1deg.nc
# 13    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-CM6-1-HR_historical_1950-2014_1deg.nc
# 14       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MRI-ESM2-0_historical_1950-2014_1deg.nc
# 15    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_ACCESS-ESM1-5_historical_1950-2014_1deg.nc
# 16        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_FGOALS-g3_historical_1950-2014_1deg.nc
# 17        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_GFDL-ESM4_historical_1950-2014_1deg.nc
# 18    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MPI-ESM1-2-LR_historical_1950-2014_1deg.nc
# 19        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_KIOST-ESM_historical_1950-2014_1deg.nc
# 20      /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_UKESM1-0-LL_historical_1950-2014_1deg.nc
# 21    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_EC-Earth3-Veg_historical_1950-2014_1deg.nc
# 22       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NorESM2-LM_historical_1950-2014_1deg.nc
# 23       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MIROC-ES2L_historical_1950-2014_1deg.nc
# 24          /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CanESM5_historical_1950-2014_1deg.nc

# %%
## extract sub-set models that will be used in the analyses
subset=['ACCESS-CM2', 'ACCESS-ESM1-5', 'BCC-CSM2-MR', 'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'EC-Earth3-Veg', 
            'FGOALS-g3', 'GFDL-CM4', 'GFDL-ESM4', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'INM-CM4-8', 'INM-CM5-0', 'KACE-1-0-G',
    'KIOST-ESM', 'MIROC-ES2L', 'MPI-ESM1-2-HR', 'MRI-ESM2-0', 'NESM3', 'NorESM2-LM', 'NorESM2-MM', 'UKESM1-0-LL', 'CanESM5', 'CanESM5', 'MPI-ESM1-2-LR']

# %%
model_paths = get_model_files_subset(data_paths, subset)
model_paths
# Out:
#          model_name  \
# 0   HadGEM3-GC31-LL
# 1        CNRM-CM6-1
# 2             NESM3
# 3         INM-CM4-8
# 4        ACCESS-CM2
# 5        KACE-1-0-G
# 6       CNRM-ESM2-1
# 7     MPI-ESM1-2-HR
# 8        NorESM2-MM
# 9          GFDL-CM4
# 10  HadGEM3-GC31-MM
# 11      BCC-CSM2-MR
# 12        INM-CM5-0
# 13    CNRM-CM6-1-HR
# 14       MRI-ESM2-0
# 15    ACCESS-ESM1-5
# 16        FGOALS-g3
# 17        GFDL-ESM4
# 18    MPI-ESM1-2-LR
# 19        KIOST-ESM
# 20      UKESM1-0-LL
# 21    EC-Earth3-Veg
# 22       NorESM2-LM
# 23       MIROC-ES2L
# 24          CanESM5
#
#                                                                                  dataset_path
# 0   /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_HadGEM3-GC31-LL_historical_1950-2014_1deg.nc
# 1        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-CM6-1_historical_1950-2014_1deg.nc
# 2             /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NESM3_historical_1950-2014_1deg.nc
# 3         /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_INM-CM4-8_historical_1950-2014_1deg.nc
# 4        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_ACCESS-CM2_historical_1950-2014_1deg.nc
# 5        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_KACE-1-0-G_historical_1950-2014_1deg.nc
# 6       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-ESM2-1_historical_1950-2014_1deg.nc
# 7     /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MPI-ESM1-2-HR_historical_1950-2014_1deg.nc
# 8        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NorESM2-MM_historical_1950-2014_1deg.nc
# 9          /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_GFDL-CM4_historical_1950-2014_1deg.nc
# 10  /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_HadGEM3-GC31-MM_historical_1950-2014_1deg.nc
# 11      /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_BCC-CSM2-MR_historical_1950-2014_1deg.nc
# 12        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_INM-CM5-0_historical_1950-2014_1deg.nc
# 13    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CNRM-CM6-1-HR_historical_1950-2014_1deg.nc
# 14       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MRI-ESM2-0_historical_1950-2014_1deg.nc
# 15    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_ACCESS-ESM1-5_historical_1950-2014_1deg.nc
# 16        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_FGOALS-g3_historical_1950-2014_1deg.nc
# 17        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_GFDL-ESM4_historical_1950-2014_1deg.nc
# 18    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MPI-ESM1-2-LR_historical_1950-2014_1deg.nc
# 19        /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_KIOST-ESM_historical_1950-2014_1deg.nc
# 20      /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_UKESM1-0-LL_historical_1950-2014_1deg.nc
# 21    /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_EC-Earth3-Veg_historical_1950-2014_1deg.nc
# 22       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_NorESM2-LM_historical_1950-2014_1deg.nc
# 23       /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_MIROC-ES2L_historical_1950-2014_1deg.nc
# 24          /g/data/w40/pn3424/2025/Lisa/Data/CMIP6/sdii_CanESM5_historical_1950-2014_1deg.nc

# %% [markdown]
# ## Calculating time series of regional-weighted average over land in CMIP6 models

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_model_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in model_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask=None)
    ts_model_dict[f'{row[0]}'] = ts_xr
print(ts_model_dict.keys())
# Out:
# dict_keys(['HadGEM3-GC31-LL', 'CNRM-CM6-1', 'NESM3', 'INM-CM4-8', 'ACCESS-CM2', 'KACE-1-0-G', 'CNRM-ESM2-1', 'MPI-ESM1-2-HR', 'NorESM2-MM', 'GFDL-CM4', 'HadGEM3-GC31-MM', 'BCC-CSM2-MR', 'INM-CM5-0', 'CNRM-CM6-1-HR', 'MRI-ESM2-0', 'ACCESS-ESM1-5', 'FGOALS-g3', 'GFDL-ESM4', 'MPI-ESM1-2-LR', 'KIOST-ESM', 'UKESM1-0-LL', 'EC-Earth3-Veg', 'NorESM2-LM', 'MIROC-ES2L', 'CanESM5'])

# %% [markdown]
# ### Align time coordinate for all models
# The models have different starting points (e.g., 1960-07-15 or 1960-07-16) depending on their calendar type. Therefore, it is necessary to align the time coordinates across all models to ensure they match.

# %%
# Define the target time coordinate
target_time = pd.date_range(start='1980-01-01', periods=35, freq='YS')  # Annual, starting 1 July

# Harmonize each model
harmonized = {}
for model, da in ts_model_dict.items():
    # Create a new DataArray with the harmonized time
    new_da = da.copy()
    new_da['time'] = target_time
    harmonized[model] = new_da

# %%
## Plot CMIP6 first

# Step 1: Combine model time series into a single DataArray
harmonized_all = xr.concat(list(harmonized.values()), dim='model', coords='minimal')
harmonized_all['model'] = list(harmonized.keys())  # label models if desired

# Step 2: Calculate statistics across models
mean_harmonized = harmonized_all.mean(dim='model')
min_harmonized = harmonized_all.min(dim='model')
max_harmonized = harmonized_all.max(dim='model')

# %%
##setting up line color 
color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'lightcoral', 
    'JRA-55':'peru', 
    'ERA5': 'deepskyblue', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}

# %%
fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])

##plot CMIP6 

ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2, linestyle='--',label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

# Axis settings
ax.set_xlabel("Time", fontsize=13)
ax.set_ylabel("sdii (mm/day)", fontsize=13)
ax.set_ylim(4, 12)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/Land_ocean_CMIP6_60N.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Reanalysis data

# %%
##direction to observational data (from FROGs database)
obs_path="/g/data/w40/pn3424/2024/Lisa/data/sdii/yr/"
obs_paths = get_model_files(obs_path)
obs_paths
# Out:
#               driving_gcm  \
# 0                    None
# 1               3B42_v7.0
# 2                    None
# 3                    None
# 4   GSMAP-NRT-gauges-v8.0
# 5                    None
# 6                    CFSR
# 7                    None
# 8                    None
# 9                    None
# 10                   None
# 11                   None
# 12                   None
# 13                   None
# 14                   None
# 15                   None
# 16        CMORPH_v1.0_CRT
# 17                   None
# 18                 MERRA2
# 19                   ERA5
# 20                   None
# 21                   None
# 22            CHIRPS_v2.0
# 23                   None
# 24                   None
# 25                   None
# 26                   None
# 27          IMERG-v07B-FC
# 28                 JRA-55
# 29                   None
# 30                   None
# 31                   None
# 32                   None
# 33                   None
# 34               CPC_v1.0
# 35         GPCC_FDD_v2022
# 36                 GIRAFE
# 37                   None
# 38                   None
# 39         REGEN_ALL_2019
# 40                   None
# 41              GPCP_V3.2
# 42                   None
# 43                   None
# 44                   None
# 45                   None
# 46         PERSIANN_v1_r1
#
#                                                                                       dataset_path
# 0             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GSMAP-gauges-NRT-v6.0_2001-2022.nc
# 1                         /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42_v7.0_1998-2019.nc
# 2                          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CHIRP_V1_1981-2022.nc
# 3                             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GSWP3_1901-2014.nc
# 4   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GSMAP-NRT-gauges-v8.0_his_1deg_2001-2023.nc
# 5                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42_MW_v7.0_1998-2019.nc
# 6                              /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CFSR_1979-2019.nc
# 7                             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_COSCH_2000-2021.nc
# 8        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_CDR_v1.3_not-enforced_1997-2021.nc
# 9           /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GSMAP-nogauges-NRT-v6.0_2001-2022.nc
# 10                /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42RT_UNCAL_v7.0_2001-2019.nc
# 11                    /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FDD_v1.0_1988-2013.nc
# 12                                              /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/grid.txt
# 13                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_TAMSAT_v3_1983-2022.nc
# 14                  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CMORPH_v1.0_RAW_1998-2017.nc
# 15                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_IMERG_V06_LU_2001-2022.nc
# 16                  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CMORPH_v1.0_CRT_1998-2021.nc
# 17                           /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_MERRA1_1979-2015.nc
# 18                           /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_MERRA2_1980-2019.nc
# 19                             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_ERA5_1979-2022.nc
# 20                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_TAMSAT_v3.1_1983-2022.nc
# 21                   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FDD_v2020_1982-2019.nc
# 22                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CHIRPS_v2.0_1981-2022.nc
# 23                          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_IP_1998-2017.nc
# 24                    /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_SM2RAIN-ASCAT_2007-2021.nc
# 25                             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_ARC2_1983-2022.nc
# 26                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42RT_v7.0_2001-2019.nc
# 27          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_IMERG-v07B-FC_his_1deg_2001-2023.nc
# 28                           /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_JRA-55_1958-2019.nc
# 29                   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FDD_v2018_1982-2016.nc
# 30                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_IMERG_V06_FC_2001-2021.nc
# 31                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_HOAPSv4.0_1996-2020.nc
# 32                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_IMERG_V06_FU_2001-2021.nc
# 33                  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_REGEN_LONG_2019_1950-2016.nc
# 34                         /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CPC_v1.0_1979-2022.nc
# 35                   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FDD_v2022_1982-2020.nc
# 36          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GIRAFE_1deg_historical_2002-2022.nc
# 37                 /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_PERSIANN_CCS_CDR_1983-2020.nc
# 38       /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_CDR_v1.3_yes-enforced_1996-2021.nc
# 39                   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_REGEN_ALL_2019_1950-2016.nc
# 40                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_TAPEER_v1.5_2011-2021.nc
# 41                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_V3.2_2000-2020.nc
# 42                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42_IR_v7.0_1998-2019.nc
# 43                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_IMERG_V06_EU_2001-2022.nc
# 44                     /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FG_v1.0_2009-2022.nc
# 45                             /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_ERAi_1979-2018.nc
# 46                   /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_PERSIANN_v1_r1_1983-2021.nc

# %%
era5=['ERA5']
era5_paths = get_model_files_subset(obs_paths, era5)
era5_paths
# Out:
#   model_name  \
# 0       ERA5
#
#                                                           dataset_path
# 0  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_ERA5_1979-2022.nc

# %%
# Initialize an empty dictionary to store time series as DataArrays
ts_era5_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in era5_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask=None)
    ts_era5_dict[f'{row[0]}'] = ts_xr
print(ts_era5_dict.keys())
# Out:
# dict_keys(['ERA5'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray 
for key in ts_era5_dict:
    da = ts_era5_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_era5_dict[key] = da.assign_coords(time=new_time)

# %%
fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])  # [left, bottom, width, height] in relative coords (0-1)

ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2,linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

# Plot in-situ and satellite datasets

for name, da in ts_era5_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 12)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/Land_Ocean_cmip6_era5_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
#### Other reanalysis

# %%
rea=['MERRA2','JRA-55','CFSR']
rea_paths = get_model_files_subset(obs_paths, rea)
rea_paths
# Out:
#   model_name  \
# 0       CFSR
# 1     MERRA2
# 2     JRA-55
#
#                                                             dataset_path
# 0    /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CFSR_1979-2019.nc
# 1  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_MERRA2_1980-2019.nc
# 2  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_JRA-55_1958-2019.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_rea_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in rea_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask=None)
    ts_rea_dict[f'{row[0]}'] = ts_xr
print(ts_rea_dict.keys())
# Out:
# dict_keys(['CFSR', 'MERRA2', 'JRA-55'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_rea_dict:
    da = ts_rea_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_rea_dict[key] = da.assign_coords(time=new_time)

# %%
fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])  # [left, bottom, width, height] in relative coords (0-1)



ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2,linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

for name, da in ts_era5_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

for name, da in ts_rea_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 12)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/Land_Ocean_CMIP6_rea_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Satelite with correction to rain gauge

# %%
sate=['3B42_v7.0','GIRAFE', 'GSMAP-NRT-gauges-v8.0','GPCP_V3.2', 'CMORPH_v1.0_CRT']

# %%
sate_paths = get_model_files_subset(obs_paths, sate)
sate_paths
# Out:
#               model_name  \
# 0              3B42_v7.0
# 1  GSMAP-NRT-gauges-v8.0
# 2        CMORPH_v1.0_CRT
# 3                 GIRAFE
# 4              GPCP_V3.2
#
#                                                                                      dataset_path
# 0                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42_v7.0_1998-2019.nc
# 1  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GSMAP-NRT-gauges-v8.0_his_1deg_2001-2023.nc
# 2                  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CMORPH_v1.0_CRT_1998-2021.nc
# 3          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GIRAFE_1deg_historical_2002-2022.nc
# 4                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_V3.2_2000-2020.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_sate_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in sate_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask=None)
    ts_sate_dict[f'{row[0]}'] = ts_xr
print(ts_sate_dict.keys())
# Out:
# dict_keys(['3B42_v7.0', 'GSMAP-NRT-gauges-v8.0', 'CMORPH_v1.0_CRT', 'GIRAFE', 'GPCP_V3.2'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_sate_dict:
    da = ts_sate_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_sate_dict[key] = da.assign_coords(time=new_time)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])  # [left, bottom, width, height] in relative coords (0-1)

ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2,linestyle='--',label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

# Plot in-situ and satellite datasets

for name, da in ts_era5_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

for name, da in ts_rea_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

for name, da in ts_sate_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 12)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/land_ocean_cmip6_all_60N.png", dpi=300, bbox_inches='tight')
plt.show()
