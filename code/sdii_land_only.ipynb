# %% [markdown]
# # Layering plots for PPT : SDII from CMIP6, Reanalyses and corrected Satellite

# %% [markdown]
# This Jupyter notebook plots time series of regionally averaged SDII over the land (50°S–50°N) from CMIP6 models, reanalyses, and satellite products. The data are sourced from the FROGs database (Roca et al., 2019), available at: https://frogs.ipsl.fr/download-data/.

# %%
## Pre-processing data first

# %%
# Import modules
# %matplotlib inline
# %run /g/data/w40/pn3424/2025/Time-series-plot/code/Functions.ipynb
import matplotlib as mpl
import fnmatch
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker as mticker
import matplotlib.gridspec as gridspec
from matplotlib.patches import Rectangle
import cartopy as cartopy
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
# Define region of interest The mainland: 5=25, 90-110
lat_slice = slice(-50,50)
lon_slice = slice(-180,180)
time_slice = slice("1980-01-01", "2014-12-30")

# Define temporal scale for SPI variable (1 for 3-months, 2 for 6-months, 3 for 12-months); use "None" if not using the SPI variable
iscale = None

# Define season as a list of month numbers. If not wanting a seasonal breakdown, use None.
# Suggestions: Wet 6-month: [10,11,12,1,2,3]; Dry 6-month: [4,5,6,7,8,9]; Wet 3-month: [12,1,2]; Dry 3-month: [6,7,8]
season =  None
season_name ='Annual' #'3-Month Wet: DJF' #'3-Month Dry: JJA' 

# Paths to mask datasets

mask_ds = xr.open_dataset('/g/data/w40/pn3424/2025/Time-series-plot/landmask_regen.nc')

# Extract masks over SEA
mask = mask_ds.land.sel(lat=lat_slice, lon=lon_slice).isel(time=0)
mask
# Out:
# <xarray.DataArray 'land' (lat: 100, lon: 360)>
# [36000 values with dtype=float32]
# Coordinates:
#     time     datetime64[ns] 1983-07-02
#   * lon      (lon) float64 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
#   * lat      (lat) float64 -49.5 -48.5 -47.5 -46.5 -45.5 ... 46.5 47.5 48.5 49.5
# Attributes:
#     long_name:     Daily PR intensity
#     units:         mm/day
#     cell_methods:  time: mean
#     comment:       This daily precipitation is calculated from the daily sour...
#     definition:    Annual total precipitation divided by the number of wet da...
#     expert_team:   ETCCDI

# %%
# Define keywords to be used with f-strings to build the path to datasets
model_type = 'gcm'
grid_type = '1degree'
time_period = 'historical'
variable = 'sdii'
temporal_resolution = 'yr'
obs_temporal_resolution = 'yr'

# Define paths to data
cmip6_data_path = '/g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/'+f'{variable}'+'/'

# %%
data_paths = get_model_files(cmip6_data_path)
pd.set_option('display.max_colwidth', None)
data_paths
# Out:
#         driving_gcm  \
# 0   HadGEM3-GC31-LL
# 1        CNRM-CM6-1
# 2             NESM3
# 3         INM-CM4-8
# 4        ACCESS-CM2
# 5        KACE-1-0-G
# 6       CNRM-ESM2-1
# 7     MPI-ESM1-2-HR
# 8        NorESM2-MM
# 9          GFDL-CM4
# 10  HadGEM3-GC31-MM
# 11      BCC-CSM2-MR
# 12        INM-CM5-0
# 13    CNRM-CM6-1-HR
# 14       MRI-ESM2-0
# 15    ACCESS-ESM1-5
# 16        FGOALS-g3
# 17        GFDL-ESM4
# 18    MPI-ESM1-2-LR
# 19        KIOST-ESM
# 20      UKESM1-0-LL
# 21    EC-Earth3-Veg
# 22       NorESM2-LM
# 23       MIROC-ES2L
# 24          CanESM5
#
#                                                                                                   dataset_path
# 0   /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_HadGEM3-GC31-LL_historical_1950-2014_1deg.nc
# 1        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-CM6-1_historical_1950-2014_1deg.nc
# 2             /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NESM3_historical_1950-2014_1deg.nc
# 3         /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_INM-CM4-8_historical_1950-2014_1deg.nc
# 4        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_ACCESS-CM2_historical_1950-2014_1deg.nc
# 5        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_KACE-1-0-G_historical_1950-2014_1deg.nc
# 6       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-ESM2-1_historical_1950-2014_1deg.nc
# 7     /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MPI-ESM1-2-HR_historical_1950-2014_1deg.nc
# 8        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NorESM2-MM_historical_1950-2014_1deg.nc
# 9          /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_GFDL-CM4_historical_1950-2014_1deg.nc
# 10  /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_HadGEM3-GC31-MM_historical_1950-2014_1deg.nc
# 11      /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_BCC-CSM2-MR_historical_1950-2014_1deg.nc
# 12        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_INM-CM5-0_historical_1950-2014_1deg.nc
# 13    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-CM6-1-HR_historical_1950-2014_1deg.nc
# 14       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MRI-ESM2-0_historical_1950-2014_1deg.nc
# 15    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_ACCESS-ESM1-5_historical_1950-2014_1deg.nc
# 16        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_FGOALS-g3_historical_1950-2014_1deg.nc
# 17        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_GFDL-ESM4_historical_1950-2014_1deg.nc
# 18    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MPI-ESM1-2-LR_historical_1950-2014_1deg.nc
# 19        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_KIOST-ESM_historical_1950-2014_1deg.nc
# 20      /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_UKESM1-0-LL_historical_1950-2014_1deg.nc
# 21    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_EC-Earth3-Veg_historical_1950-2014_1deg.nc
# 22       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NorESM2-LM_historical_1950-2014_1deg.nc
# 23       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MIROC-ES2L_historical_1950-2014_1deg.nc
# 24          /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CanESM5_historical_1950-2014_1deg.nc

# %%
subset=['ACCESS-CM2', 'ACCESS-ESM1-5', 'BCC-CSM2-MR', 'CNRM-CM6-1', 'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'EC-Earth3-Veg', 
            'FGOALS-g3', 'GFDL-CM4', 'GFDL-ESM4', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'INM-CM4-8', 'INM-CM5-0', 'KACE-1-0-G',
    'KIOST-ESM', 'MIROC-ES2L', 'MPI-ESM1-2-HR', 'MRI-ESM2-0', 'NESM3', 'NorESM2-LM', 'NorESM2-MM', 'UKESM1-0-LL', 'CanESM5', 'CanESM5', 'MPI-ESM1-2-LR']

# %%
model_paths = get_model_files_subset(data_paths, subset)
model_paths
# Out:
#          model_name  \
# 0   HadGEM3-GC31-LL
# 1        CNRM-CM6-1
# 2             NESM3
# 3         INM-CM4-8
# 4        ACCESS-CM2
# 5        KACE-1-0-G
# 6       CNRM-ESM2-1
# 7     MPI-ESM1-2-HR
# 8        NorESM2-MM
# 9          GFDL-CM4
# 10  HadGEM3-GC31-MM
# 11      BCC-CSM2-MR
# 12        INM-CM5-0
# 13    CNRM-CM6-1-HR
# 14       MRI-ESM2-0
# 15    ACCESS-ESM1-5
# 16        FGOALS-g3
# 17        GFDL-ESM4
# 18    MPI-ESM1-2-LR
# 19        KIOST-ESM
# 20      UKESM1-0-LL
# 21    EC-Earth3-Veg
# 22       NorESM2-LM
# 23       MIROC-ES2L
# 24          CanESM5
#
#                                                                                                   dataset_path
# 0   /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_HadGEM3-GC31-LL_historical_1950-2014_1deg.nc
# 1        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-CM6-1_historical_1950-2014_1deg.nc
# 2             /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NESM3_historical_1950-2014_1deg.nc
# 3         /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_INM-CM4-8_historical_1950-2014_1deg.nc
# 4        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_ACCESS-CM2_historical_1950-2014_1deg.nc
# 5        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_KACE-1-0-G_historical_1950-2014_1deg.nc
# 6       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-ESM2-1_historical_1950-2014_1deg.nc
# 7     /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MPI-ESM1-2-HR_historical_1950-2014_1deg.nc
# 8        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NorESM2-MM_historical_1950-2014_1deg.nc
# 9          /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_GFDL-CM4_historical_1950-2014_1deg.nc
# 10  /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_HadGEM3-GC31-MM_historical_1950-2014_1deg.nc
# 11      /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_BCC-CSM2-MR_historical_1950-2014_1deg.nc
# 12        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_INM-CM5-0_historical_1950-2014_1deg.nc
# 13    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CNRM-CM6-1-HR_historical_1950-2014_1deg.nc
# 14       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MRI-ESM2-0_historical_1950-2014_1deg.nc
# 15    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_ACCESS-ESM1-5_historical_1950-2014_1deg.nc
# 16        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_FGOALS-g3_historical_1950-2014_1deg.nc
# 17        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_GFDL-ESM4_historical_1950-2014_1deg.nc
# 18    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MPI-ESM1-2-LR_historical_1950-2014_1deg.nc
# 19        /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_KIOST-ESM_historical_1950-2014_1deg.nc
# 20      /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_UKESM1-0-LL_historical_1950-2014_1deg.nc
# 21    /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_EC-Earth3-Veg_historical_1950-2014_1deg.nc
# 22       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_NorESM2-LM_historical_1950-2014_1deg.nc
# 23       /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_MIROC-ES2L_historical_1950-2014_1deg.nc
# 24          /g/data/w40/pn3424/2025/Time-series-plot/Data/CMIP6/sdii/sdii_CanESM5_historical_1950-2014_1deg.nc

# %% [markdown]
# ## REGEN only

# %%
OBS="/g/data/w40/pn3424/2024/Lisa/data/" +f'{variable}' +f"/{temporal_resolution}/"

obs_paths = get_model_files(OBS)
pd.set_option('display.max_colwidth', None)
obs_paths

insitu=['REGEN_ALL_2019']

# %%
regen_paths = get_model_files_subset(obs_paths, insitu)
regen_paths
# Out:
#        model_name  \
# 0  REGEN_ALL_2019
#
#                                                                     dataset_path
# 0  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_REGEN_ALL_2019_1950-2016.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_regen_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in regen_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_regen_dict[f'{row[0]}'] = ts_xr
print(ts_regen_dict.keys())
# Out:
# dict_keys(['REGEN_ALL_2019'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_regen_dict:
    da = ts_regen_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_regen_dict[key] = da.assign_coords(time=new_time)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75]) 
# [left, bottom, width, height] in relative coords (0-1)

color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'light coral', 
    'JRA-55':'peru', 
    'ERA5': 'deepbluesky', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}


# Plot in-situ and satellite datasets
for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Time-series-plot/Figure/Land_regen_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Calculating time series of regional-weighted average over land

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_model_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in model_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_model_dict[f'{row[0]}'] = ts_xr
print(ts_model_dict.keys())
# Out:
# dict_keys(['HadGEM3-GC31-LL', 'CNRM-CM6-1', 'NESM3', 'INM-CM4-8', 'ACCESS-CM2', 'KACE-1-0-G', 'CNRM-ESM2-1', 'MPI-ESM1-2-HR', 'NorESM2-MM', 'GFDL-CM4', 'HadGEM3-GC31-MM', 'BCC-CSM2-MR', 'INM-CM5-0', 'CNRM-CM6-1-HR', 'MRI-ESM2-0', 'ACCESS-ESM1-5', 'FGOALS-g3', 'GFDL-ESM4', 'MPI-ESM1-2-LR', 'KIOST-ESM', 'UKESM1-0-LL', 'EC-Earth3-Veg', 'NorESM2-LM', 'MIROC-ES2L', 'CanESM5'])

# %%
##align time cor for all models

# %%
import xarray as xr
import numpy as np
import pandas as pd

# Define the target time coordinate
target_time = pd.date_range(start='1980-01-01', periods=35, freq='YS')  # Annual, starting 1 July

# Harmonize each model
harmonized = {}
for model, da in ts_model_dict.items():
    # Create a new DataArray with the harmonized time
    new_da = da.copy()
    new_da['time'] = target_time
    harmonized[model] = new_da

# %%
import matplotlib.pyplot as plt
import xarray as xr

# ts_model_dict = {'model1': ts1, 'model2': ts2, ...}

# Step 1: Combine model time series into a single DataArray
harmonized_all = xr.concat(list(harmonized.values()), dim='model', coords='minimal')
harmonized_all['model'] = list(harmonized.keys())  # label models if desired

# Step 2: Calculate statistics across models
mean_harmonized = harmonized_all.mean(dim='model')
min_harmonized = harmonized_all.min(dim='model')
max_harmonized = harmonized_all.max(dim='model')

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])

color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'light coral', 
    'JRA-55':'peru', 
    'ERA5': 'deepbluesky', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}

# Plot CMIP6 model range

# Plot in-situ and satellite datasets
for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2,linestyle='--',label='CMIP6 MMM')

ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

# Axis settings
ax.set_xlabel("Time", fontsize=13)
ax.set_ylabel("sdii (mm/day)", fontsize=13)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)

plt.savefig("/g/data/w40/pn3424/2025/Time-series-plot/Figure/Land_regen_CMIP6_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## for OBS data

# %%
obs_path="/g/data/w40/pn3424/2024/Lisa/data/sdii/yr/"

obs_paths = get_model_files(obs_path)
pd.set_option('display.max_colwidth', None)
obs_paths

insitu2=['CPC_v1.0']
insitu3=['CPC_v1.0','GPCC_FDD_v2022']
##'GPCC_FDD_v2022', 'REGEN_ALL_2019'

# %%
insitu2_paths = get_model_files_subset(obs_paths, insitu2)
insitu2_paths
# Out:
#   model_name  \
# 0   CPC_v1.0
#
#                                                               dataset_path
# 0  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CPC_v1.0_1979-2022.nc

# %%
insitu3_paths = get_model_files_subset(obs_paths, insitu3)
insitu3_paths
# Out:
#        model_name  \
# 0        CPC_v1.0
# 1  GPCC_FDD_v2022
#
#                                                                     dataset_path
# 0        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CPC_v1.0_1979-2022.nc
# 1  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCC_FDD_v2022_1982-2020.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_insitu2_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in insitu2_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_insitu2_dict[f'{row[0]}'] = ts_xr
print(ts_insitu2_dict.keys())
# Out:
# dict_keys(['CPC_v1.0'])

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_insitu3_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in insitu3_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_insitu3_dict[f'{row[0]}'] = ts_xr
print(ts_insitu3_dict.keys())
# Out:
# dict_keys(['CPC_v1.0', 'GPCC_FDD_v2022'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_insitu2_dict:
    da = ts_insitu2_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_insitu2_dict[key] = da.assign_coords(time=new_time)

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_insitu3_dict:
    da = ts_insitu3_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_insitu3_dict[key] = da.assign_coords(time=new_time)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75]) 
# [left, bottom, width, height] in relative coords (0-1)

color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'light coral', 
    'JRA-55':'peru', 
    'ERA5': 'deepbluesky', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}
for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)
    
ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2, linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')
    
for name, da in ts_insitu2_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)
    


# Plot in-situ and satellite datasets


# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Land_regen_CMIP6_insitu2_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75]) 
# [left, bottom, width, height] in relative coords (0-1)

color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'light coral', 
    'JRA-55':'peru', 
    'ERA5': 'deepbluesky', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}
for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)
    
ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2, linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

    
for name, da in ts_insitu3_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Plot in-situ and satellite datasets


# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/Land_regen_CMIP6_insitu3_50N.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 65
#      62 ax.tick_params(axis='x', labelsize=12)
#      63 ax.tick_params(axis='y', labelsize=12)
# ---> 65 plt.savefig("/g/data/w40/pn3424/2025/Lisa/Figure/Land_regen_CMIP6_insitu3_50N.png", dpi=300, bbox_inches='tight')
#      66 plt.show()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
#    3374     for ax in self.axes:
#    3375         stack.enter_context(
#    3376             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3378 self.canvas.print_figure(fname, **kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/backend_bases.py:2366, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2362 try:
#    2363     # _get_renderer may change the figure dpi (as vector formats
#    2364     # force the figure dpi to 72), so we need to set it again here.
#    2365     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366         result = print_method(
#    2367             filename,
#    2368             facecolor=facecolor,
#    2369             edgecolor=edgecolor,
#    2370             orientation=orientation,
#    2371             bbox_inches_restore=_bbox_inches_restore,
#    2372             **kwargs)
#    2373 finally:
#    2374     if bbox_inches and restore_bbox:
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/backend_bases.py:2232, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2228     optional_kws = {  # Passed by print_figure for other renderers.
#    2229         "dpi", "facecolor", "edgecolor", "orientation",
#    2230         "bbox_inches_restore"}
#    2231     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234 else:  # Let third-parties do as they see fit.
#    2235     print_method = meth
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:458, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     453 """
#     454 Draw the canvas, then save it using `.image.imsave` (to which
#     455 *pil_kwargs* and *metadata* are forwarded).
#     456 """
#     457 FigureCanvasAgg.draw(self)
# --> 458 mpl.image.imsave(
#     459     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/matplotlib/image.py:1689, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687 pil_kwargs.setdefault("format", format)
#    1688 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689 image.save(fname, **pil_kwargs)
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.04/lib/python3.9/site-packages/PIL/Image.py:2317, in Image.save(self, fp, format, **params)
#    2315         fp = builtins.open(filename, "r+b")
#    2316     else:
# -> 2317         fp = builtins.open(filename, "w+b")
#    2319 try:
#    2320     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/g/data/w40/pn3424/2025/Lisa/Figure/Land_regen_CMIP6_insitu3_50N.png'

# %% [markdown]
# ## Satelite with correction to rain gauge

# %%
sate=['3B42_v7.0','GIRAFE', 'GSMAP-NRT-gauges-v8.0',
             'CHIRPS_v2.0','GPCP_V3.2', 'CMORPH_v1.0_CRT']

# %%
sate_paths = get_model_files_subset(obs_paths, sate)
sate_paths
# Out:
#               model_name  \
# 0              3B42_v7.0
# 1  GSMAP-NRT-gauges-v8.0
# 2        CMORPH_v1.0_CRT
# 3            CHIRPS_v2.0
# 4                 GIRAFE
# 5              GPCP_V3.2
#
#                                                                                      dataset_path
# 0                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_3B42_v7.0_1998-2019.nc
# 1  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GSMAP-NRT-gauges-v8.0_his_1deg_2001-2023.nc
# 2                  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CMORPH_v1.0_CRT_1998-2021.nc
# 3                      /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CHIRPS_v2.0_1981-2022.nc
# 4          /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_ANN_GIRAFE_1deg_historical_2002-2022.nc
# 5                        /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_GPCP_V3.2_2000-2020.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_sate_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in sate_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_sate_dict[f'{row[0]}'] = ts_xr
print(ts_sate_dict.keys())
# Out:
# dict_keys(['3B42_v7.0', 'GSMAP-NRT-gauges-v8.0', 'CMORPH_v1.0_CRT', 'CHIRPS_v2.0', 'GIRAFE', 'GPCP_V3.2'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_sate_dict:
    da = ts_sate_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_sate_dict[key] = da.assign_coords(time=new_time)

# %%
ts_sate_dict
# Out:
# {'3B42_v7.0': <xarray.DataArray 'sdii' (time: 17)>
#  array([8.93694382, 8.68269888, 8.53500716, 8.16133204, 8.09002967,
#         8.30694506, 8.27260545, 8.24503486, 8.29373165, 8.27707367,
#         8.19896493, 8.13317894, 8.28171484, 8.25736758, 8.16067433,
#         8.23772406, 8.18332815])
#  Coordinates:
#    * time     (time) datetime64[ns] 1998-01-01 1999-01-01 ... 2014-01-01,
#  'GSMAP-NRT-gauges-v8.0': <xarray.DataArray 'sdii' (time: 15)>
#  array([8.57263959, 8.3206008 , 8.08208077, 7.99032863, 8.0853376 ,
#         7.78734266, 7.73656214, 7.64284792, 7.6373196 , 7.48777475,
#         7.86420437, 7.61997553, 7.4895215 , 7.30145812, 7.20892812])
#  Coordinates:
#    * time     (time) datetime64[ns] 2000-01-01 2001-01-01 ... 2014-01-01,
#  'CMORPH_v1.0_CRT': <xarray.DataArray 'sdii' (time: 17)>
#  array([7.50830266, 7.40050401, 7.63309791, 7.58969139, 7.59337066,
#         7.78706189, 7.88825183, 7.67791736, 7.64550106, 7.82755548,
#         7.73557157, 7.79399139, 8.01187986, 7.85552648, 7.76258981,
#         7.73447106, 7.69989417])
#  Coordinates:
#    * time     (time) datetime64[ns] 1998-01-01 1999-01-01 ... 2014-01-01,
#  'CHIRPS_v2.0': <xarray.DataArray 'sdii' (time: 34)>
#  array([8.05526226, 7.74704876, 7.83106289, 7.67118006, 7.83100434,
#         7.84598228, 7.60348109, 8.13210374, 7.98491326, 7.83579047,
#         7.90357176, 7.70434357, 7.57678348, 7.78106816, 7.8802711 ,
#         7.99300915, 7.84797122, 7.97973099, 7.87209252, 8.06586514,
#         7.88963972, 7.85736521, 8.01277779, 8.00791503, 8.02360006,
#         7.99451631, 7.99091059, 8.04947211, 7.99720695, 8.19640668,
#         8.2364506 , 8.02709407, 8.04821977, 7.89801134])
#  Coordinates:
#    * time     (time) datetime64[ns] 1981-01-01 1982-01-01 ... 2014-01-01,
#  'GIRAFE': <xarray.DataArray 'sdii' (time: 13)>
#  array([8.92756474, 9.16579238, 8.47135303, 8.36432564, 8.18199764,
#         8.2993553 , 8.62921398, 8.44714229, 8.43221497, 8.48573142,
#         7.71200515, 7.77465909, 7.68114115])
#  Coordinates:
#    * time     (time) datetime64[ns] 2002-01-01 2003-01-01 ... 2014-01-01,
#  'GPCP_V3.2': <xarray.DataArray 'sdii' (time: 15)>
#  array([       nan, 7.4945561 , 7.56640843, 7.70545868, 7.76730896,
#         7.76810623, 7.84781406, 7.87257917, 7.80150805, 7.67654632,
#         7.92958397, 7.85723689, 7.65025831, 7.79103203, 7.58051212])
#  Coordinates:
#    * time     (time) datetime64[ns] 2000-01-01 2001-01-01 ... 2014-01-01}

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])  # [left, bottom, width, height] in relative coords (0-1)
color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'lightcoral', 
    'JRA-55':'peru', 
    'ERA5': 'deepbluesky', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}


for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)
    
ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2, linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

    
for name, da in ts_insitu3_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Plot in-situ and satellite datasets

for name, da in ts_sate_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Time-series-plot/Figure/Land_regen_CMIP6_insitu_sate_50N.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## with reanalysese

# %%
rea=['MERRA2','JRA-55', 'ERA5', 'CFSR']
rea_paths = get_model_files_subset(obs_paths, rea)
rea_paths
# Out:
#   model_name  \
# 0       CFSR
# 1     MERRA2
# 2       ERA5
# 3     JRA-55
#
#                                                             dataset_path
# 0    /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_CFSR_1979-2019.nc
# 1  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_MERRA2_1980-2019.nc
# 2    /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_ERA5_1979-2022.nc
# 3  /g/data/w40/pn3424/2024/Lisa/data/sdii/yr/sdii_yr_JRA-55_1958-2019.nc

# %%
# Initialize an empty dictionary to store model time series as DataArrays
ts_rea_dict = {}

# Loop through RCM simulations and calculate the model bias; store in a dictionary
for i, row in rea_paths.iterrows():
    ts_xr=get_weighted_ts(row[1], variable, time_slice, lat_slice, lon_slice, season, iscale, mask)
    ts_rea_dict[f'{row[0]}'] = ts_xr
print(ts_rea_dict.keys())
# Out:
# dict_keys(['CFSR', 'MERRA2', 'ERA5', 'JRA-55'])

# %%
import pandas as pd

# Harmonize the time axis in each DataArray
for key in ts_rea_dict:
    da = ts_rea_dict[key]
    # Replace time with a new datetime index: January 1st of each year
    years = da['time'].dt.year
    new_time = xr.DataArray(
        pd.to_datetime([f"{y}-01-01" for y in years.values]),
        dims='time'
    )
    ts_rea_dict[key] = da.assign_coords(time=new_time)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 5))  # Total figure size in inches
ax = fig.add_axes([0.1, 0.15, 0.65, 0.75])  # [left, bottom, width, height] in relative coords (0-1)
color_map = {
    'CPC_v1.0': 'orange',
    'GPCC_FDD_v2022': 'green',
    'REGEN_ALL_2019': 'red',
    '3B42_v7.0':'blue',
    'GIRAFE':'cyan', 
    'GSMAP-NRT-gauges-v8.0':'darkgreen', 
    'IMERG-v07B-FC':'maroon', 
    'PERSIANN_v1_r1':'yellow', 
    'CHIRPS_v2.0':'navy',
    'GPCP_V3.2':'teal', 
    'CMORPH_v1.0_CRT':'hotpink', 
    'MERRA2': 'lightcoral', 
    'JRA-55':'peru', 
    'ERA5': 'deepskyblue', 
    'CFSR':'orchid'
    # Add more mappings if you have more datasets
}

for name, da in ts_regen_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)
    
ax.plot(mean_harmonized['time'], mean_harmonized, color='black', linewidth=2, linestyle='--', label='CMIP6 MMM')

# Plot CMIP6 model range
ax.fill_between(mean_harmonized['time'], min_harmonized, max_harmonized, 
                color='pink', alpha=0.1, label='CMIP6 Range')

# Plot in-situ and satellite datasets
for name, da in ts_insitu3_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

for name, da in ts_sate_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

for name, da in ts_rea_dict.items():
    color = color_map.get(name, 'black')
    ax.plot(da['time'], da, label=name, linewidth=2, color=color)

# Axis settings
ax.set_xlabel("Time", fontsize=11)
ax.set_ylabel("sdii (mm/day)", fontsize=11)
ax.set_ylim(4, 10)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
ax.minorticks_on()

# Legend: outside and fixed
legend = fig.legend(
    loc='upper left',
    bbox_to_anchor=(0.78, 0.9),
    frameon=False,
    fontsize=9,
    markerscale=1.5,
    labelspacing=0.4,
    handlelength=2.5,
    borderaxespad=0.5
)
ax.tick_params(axis='x', labelsize=12)
ax.tick_params(axis='y', labelsize=12)

plt.savefig("/g/data/w40/pn3424/2025/Time-series-plot/Figure/land_regen_CMIP6_insitu_sate_rea_50N.png", dpi=300, bbox_inches='tight')
plt.show()
